# %% [markdown]
# ## Cluster Analysis of Solar Projects in NY without large-scale industrial installations

# %% [markdown]
# ###### This script contains the following:
# #### 1. Importing libraries and data
# #### 2. Pre-processing data
# ##### 2.1 Removing categorical columns
# ##### 2.2 Standardise data
# ##### 2.3 Principal component analysis
# #### 3. The elbow technique
# #### 4. K-means clustering

# %% [markdown]
# ### 1. Importing libraries and data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans # Here is where you import the k-means algorithm from scikit-learn.
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pylab as pl # PyLab is a convenience module that bulk imports matplotlib.

# %%
# This option ensures the graphs you create are displayed in your notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
path = r'C:\Users\isobr\OneDrive\02052023Solar Programs NY\02. Prepared data'

# %%
df = pd.read_pickle(os.path.join(path,'solar_no_outliers.pkl'))

# %%
df.shape
# Out:
# (70970, 22)

# %%
df.head()
# Out:
#    index project_number           city    county state  zip_code       sector  \
# 0      0     5137-49041          Maine    Broome    NY     13802  Residential
# 1      1     5137-46019      Levittown    Nassau    NY     11756  Residential
# 2      2     5137-52151       Cortland  Cortland    NY     13045  Residential
# 3      3     5129-94109  Staten Island  Richmond    NY     10314  Residential
# 4      4     5137-46454        Warwick    Orange    NY     10990  Residential
#
#                    program_type               electric_utility purchase_type  \
# 0  Residential/Small Commercial           NYS Electric and Gas         Lease
# 1  Residential/Small Commercial               PSEG Long Island         Lease
# 2  Residential/Small Commercial                  National Grid         Lease
# 3  Residential/Small Commercial            Consolidated Edison      Purchase
# 4  Residential/Small Commercial  Orange and Rockland Utilities         Lease
#
#    ... inverter_quantity pv_quantity  project_cost  incentive  kw_dc  \
# 0  ...               2.0        40.0      41800.00     6930.0  10.00
# 1  ...               1.0        28.0      30940.00     2520.0   7.00
# 2  ...               2.0        49.0      48387.50    11025.0  12.25
# 3  ...               1.0        15.0      23509.54     2943.0   4.91
# 4  ...               1.0        22.0      25283.00     5720.0   5.72
#
#    kwh_year  affordable_solar  community_distributed_generation  \
# 0   11738.0             False                             False
# 1    8217.0             False                             False
# 2   14380.0             False                             False
# 3    5758.0             False                             False
# 4    6714.0             False                             False
#
#                                       location_data  installation_size
# 0          Maine, NY 13802\n(42.240938, -76.047937)        Small Solar
# 1      Levittown, NY 11756\n(40.725845, -73.517198)        Small Solar
# 2       Cortland, NY 13045\n(42.588691, -76.185061)        Small Solar
# 3  Staten Island, NY 10314\n(40.604049, -74.152798)        Small Solar
# 4        Warwick, NY 10990\n(41.263165, -74.365461)        Small Solar
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['index', 'project_number', 'city', 'county', 'state', 'zip_code',
#        'sector', 'program_type', 'electric_utility', 'purchase_type',
#        'date_application_received', 'project_status', 'inverter_quantity',
#        'pv_quantity', 'project_cost', 'incentive', 'kw_dc', 'kwh_year',
#        'affordable_solar', 'community_distributed_generation', 'location_data',
#        'installation_size'],
#       dtype='object')

# %% [markdown]
# ### 2. Pre-processing data

# %% [markdown]
# #### 2.1 Removing categorical columns

# %%
#need to remove categorical data columns
df1=df.drop(columns=['index','project_number', 'city', 'county', 'state', 'zip_code',
       'sector', 'program_type', 'electric_utility', 'purchase_type',
       'date_application_received', 'project_status', 'affordable_solar', 'community_distributed_generation', 'location_data','installation_size'])

# %%
df1.head()
# Out:
#    inverter_quantity  pv_quantity  project_cost  incentive  kw_dc  kwh_year
# 0                2.0         40.0      41800.00     6930.0  10.00   11738.0
# 1                1.0         28.0      30940.00     2520.0   7.00    8217.0
# 2                2.0         49.0      48387.50    11025.0  12.25   14380.0
# 3                1.0         15.0      23509.54     2943.0   4.91    5758.0
# 4                1.0         22.0      25283.00     5720.0   5.72    6714.0

# %% [markdown]
# ### 3. The elbow technique

# %% [markdown]
# Although we could use the resulting dataframe from the component analysis as input for the cluster analysis, here I chose to continue with the six variables, to gain some information on how they vary

# %%
num_cl = range(1, 10) # Defines the range of potential clusters in the data.
kmeans = [KMeans(n_clusters=i) for i in num_cl] # Defines k-means clusters in the range assigned above.

# %%
score = [kmeans[i].fit(df1).score(df1) for i in range(len(kmeans))] # Creates a score that represents 
# a rate of variation for the given cluster option.

score
# Out:
# [-18563661096409.547,
#  -7901688023214.97,
#  -5006257324198.989,
#  -3777331620976.061,
#  -2996265346167.853,
#  -2375685984823.699,
#  -2040664136203.4075,
#  -1821878883365.5474,
#  -1647744886221.1443]

# %%
# Plot the elbow curve using PyLab.

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# With the elbow curve in this dataset we see we can create 3 clusters with some variance

# %% [markdown]
# ### 4. K-means clustering

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 3)

# %%
# Fit the k-means object to the data.

kmeans.fit(df1)
# Out:
# KMeans(n_clusters=3)

# %%
df1['clusters'] = kmeans.fit_predict(df1)

# %%
df1.head()
# Out:
#    inverter_quantity  pv_quantity  project_cost  incentive  kw_dc  kwh_year  \
# 0                2.0         40.0      41800.00     6930.0  10.00   11738.0
# 1                1.0         28.0      30940.00     2520.0   7.00    8217.0
# 2                2.0         49.0      48387.50    11025.0  12.25   14380.0
# 3                1.0         15.0      23509.54     2943.0   4.91    5758.0
# 4                1.0         22.0      25283.00     5720.0   5.72    6714.0
#
#    clusters
# 0         2
# 1         2
# 2         1
# 3         0
# 4         0

# %%
df1['clusters'].value_counts()
# Out:
# 0    32374
# 2    28473
# 1    10123
# Name: clusters, dtype: int64

# %%
# Plot the clusters for the "incentive" and "project_cost" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df1['incentive'], y=df1['project_cost'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Incentives') # Label x-axis.
plt.ylabel('Project Cost') # Label y-axis.
plt.show()

# %%
# Plot the clusters for project_cost  and kwh_year variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df1['kwh_year'], y=df1['project_cost'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Annual Energy Produced in Kwh') # Label x-axis.
plt.ylabel('Project Cost') # Label y-axis.
plt.show()

# %%
#using loc function to create a cluster column/category - using big, medium and small, although all installations are small, since this df does not include outliers
df1.loc[df1['clusters'] == 0, 'cluster'] = 'large'
df1.loc[df1['clusters'] == 1, 'cluster'] = 'small'
df1.loc[df1['clusters'] == 2, 'cluster'] = 'medium'

# %%
# use group by to compare clusters for inverter_quantity, pv_quantity, project_cost, incentive, kw_dc, kwh_year
df1.groupby('cluster').agg({'inverter_quantity':['mean', 'median'], 
                         'pv_quantity':['mean', 'median'], 
                         'project_cost':['mean', 'median'],
                          'incentive':['mean', 'median'],
                          'kw_dc':['mean', 'median'],
                          'kwh_year':['mean', 'median']})
# Out:
#         inverter_quantity        pv_quantity         project_cost           \
#                      mean median        mean median          mean   median
# cluster
# large            7.122011    1.0   18.924106   18.0  20310.689186  20985.0
# medium           9.209181    1.0   30.355776   30.0  36829.034146  36200.0
# small            9.651388    2.0   43.667391   42.0  59632.839049  56350.0
#
#            incentive              kw_dc             kwh_year
#                 mean  median       mean median          mean   median
# cluster
# large    2676.425201  2184.0   5.112183   4.95   5999.921264   5811.0
# medium   4968.289683  3952.0   8.417455   8.16   9879.848207   9579.0
# small    7549.991366  5642.0  11.900270  11.70  13968.180283  13734.0

# %% [markdown]
# Nevertheless, the clusters show there are roughly three groups within the residential installations, from very low costs and energy produced to a fairly high energy produced/cost.

# %%
df.to_excel(r'C:\Users\isobr\OneDrive\02052023Solar Programs NY\02. Prepared data\export_solPro.xlsx', index=False)

# %%
df1.to_excel(r'C:\Users\isobr\OneDrive\02052023Solar Programs NY\02. Prepared data\export_solclu.xlsx', index=False)
