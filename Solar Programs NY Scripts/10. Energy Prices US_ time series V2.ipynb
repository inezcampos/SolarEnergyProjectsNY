# %% [markdown]
# ## Time Series Analsyis of US Energy Information

# %% [markdown]
# ##### The data used shows the receipts of fossil fuels by electrictiy plants for all sectors in New York state

# %% [markdown]
# ### This script contains:
# ##### 1. Importing your libraries and data
# ##### 2. Subsetting, wrangling, and cleaning time-series data
# ##### 3. Time series analysis: decomposition
# ##### 4. Testing for stationarity
# ##### 5. Stationarizing US Energy Information on Fossil Fuel Receipts
# ##### 6. Forecasting with ARIMA

# %% [markdown]
# ### 1. Importing your libraries and data

# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm # Using .api imports the public access version of statsmodels, which is a library that handles 
# statistical models.
import os
import warnings # This is a library that handles warnings.

warnings.filterwarnings("ignore") # Disable deprecation warnings that could indicate, for instance, a suspended library or 
# feature. These are more relevant to developers and very seldom to analysts.

plt.style.use('fivethirtyeight') # This is a styling option for how your plots will appear. More examples here:
# https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html
# https://matplotlib.org/3.1.0/gallery/style_sheets/fivethirtyeight.html

# %%
# Configure API key 

quandl.ApiConfig.api_key = 'DWdFN7ysWCPB6skng1jr'

# %%
# Importing data from the US Energy Information Administration data, variable: "Receipts of fossil fuels by electricity plants ; natural gas ; New York ; all sectors ; monthly"

data = quandl.get('EIA/ELEC_RECEIPTS_NG_NY_99_M')

# %% [markdown]
# The reason for choosing this data: it shows another side to NY state's energy consumption, now looking into fossil fuel consumption. The data starts in 2008, and goes up to 2021, with no forecasted values. Because it is monthly data it is likely to have some seasonality.

# %%
data.head(5)
# Out:
#                 Value
# Date
# 2008-01-31  28637.792
# 2008-02-29  26530.254
# 2008-03-31  30553.781
# 2008-04-30  28445.590
# 2008-05-31  29732.058

# %%
data.shape
# Out:
# (167, 1)

# %%
data.columns
# Out:
# Index(['Value'], dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100) # The dpi argument controls the quality of the visualization here. When it's set to 100,
# it will produce lower-than-standard quality, which is useful if, similar to this notebook, you'll have a lot of plots.
# A large number of plots will increase the size of the notebook, which could take more time to load and eat up a lot of RAM!

plt.plot(data)

# %% [markdown]
# I will look into all records except for 2008, which is likely an outlie years since it matches the recession period, when energy consumption has generally dropped (and therefore receipts for fossil fuels are likely to have also lower values).

# %% [markdown]
# ### 2. Subsetting, wrangling, and cleaning time-series data

# %%
# Reset index so that you can use the "Date" column as a filter

data_2 = data.reset_index()

# %%
data_2.head()
# Out:
#         Date      Value
# 0 2008-01-31  28637.792
# 1 2008-02-29  26530.254
# 2 2008-03-31  30553.781
# 3 2008-04-30  28445.590
# 4 2008-05-31  29732.058

# %%
data_sub = data_2.loc[(data_2['Date'] > '2008-12-31')] #sub-setting by excluding 2008 records only

# %%
data_sub.shape
# Out:
# (155, 2)

# %%
data_sub.head(8)
# Out:
#          Date      Value
# 12 2009-01-31  26823.643
# 13 2009-02-28  27090.215
# 14 2009-03-31  31458.670
# 15 2009-04-30  30244.911
# 16 2009-05-31  29595.668
# 17 2009-06-30  31934.077
# 18 2009-07-31  39471.685
# 19 2009-08-31  48586.491

# %%
# Set the "Date" column as the index

from datetime import datetime

data_sub['datetime'] = pd.to_datetime(data_sub['Date']) # Create a datetime column from "Date.""
data_sub = data_sub.set_index('datetime') # Set the datetime as the index of the dataframe.
data_sub.drop(['Date'], axis=1, inplace=True) # Drop the "Date" column.
data_sub.head()
# Out:
#                 Value
# datetime
# 2009-01-31  26823.643
# 2009-02-28  27090.215
# 2009-03-31  31458.670
# 2009-04-30  30244.911
# 2009-05-31  29595.668

# %%
# Plot the new data set

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_sub)

# %% [markdown]
# The data has first an upward trend than a downward trend, it does not appear stationary

# %%
# Check for missing values 

data_sub.isnull().sum()
# Out:
# Value    0
# dtype: int64

# %%
# Check for duplicates

dups = data_sub.duplicated()
dups.sum()

# No dups!
# Out:
# 0

# %% [markdown]
# ### 3. Time-series analysis: decomposition

# %%
# Decompose the time series using an additive model

decomposition = sm.tsa.seasonal_decompose(data_sub, model='additive')

# %%
from pylab import rcParams # This will define a fixed size for all special charts.

rcParams['figure.figsize'] = 18, 7

# %%
# Plot the separate components

decomposition.plot()
plt.show()

# %% [markdown]
# There is a seasonality which is expectable since we are looking at monthly receipts and energy needs tend very between months/seasons, we can also see some noise and the trend seens to show a mean value which is not constant, so the dataset does not seem to be stationary.

# %% [markdown]
# ### 4. Testing for stationarity

# %%
# The adfuller() function will import from the model from statsmodels for the test; however, running it will only return 
# an array of numbers. This is why I need to define a function that prints the correct output from that array.

from statsmodels.tsa.stattools import adfuller # Import the adfuller() function

def dickey_fuller(timeseries): # Define the function
    # Perform the Dickey-Fuller test:
    print ('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in test[4].items():
       result['Critical Value (%s)'%key] = value
    print (result)

# Apply the test using the function on the time series
dickey_fuller(data_sub['Value'])
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                  -2.157549
# p-value                          0.222012
# Number of Lags Used             13.000000
# Number of Observations Used    141.000000
# Critical Value (1%)             -3.477601
# Critical Value (5%)             -2.882266
# Critical Value (10%)            -2.577822
# dtype: float64

# %% [markdown]
# In this case, the test statistics is larger than the critical value so i can't reject the null hypothesis (If the test statistic is larger than the critical value, I can’t reject the null hypothesis. If the test statistic is smaller, then I can reject the null hypothesis). Also, the p-value is higher than 0.05, which indicates this result is not significant. Moving on to testing for autocorrelation to help understand if the data is stationary.

# %%
# Check out a plot of autocorrelations

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf # Here, you import the autocorrelation and partial correlation plots

plot_acf(data_sub)
plt.show()

# %% [markdown]
# There are some autocorrelations which indicate that the stationarity of the data is weak. We have some lags that go above the blue edge indicating these lags are significantly correlated to each other. Although we only have five lags that are out of the confidence interval.

# %% [markdown]
# ### 5. Stationarizing US Energy Information on Fossil Fuel Receipts

# %%
data_diff = data_sub - data_sub.shift(1) # The df.shift(1) function turns the observation to t-1, making the whole thing t - (t -1)

# %%
data_diff.dropna(inplace = True) # Here, remove the missing values that came about as a result of the differencing. 
# You need to remove these or you won't be able to run the Dickey-Fuller test.

# %%
data_diff.head()
# Out:
#                Value
# datetime
# 2009-02-28   266.572
# 2009-03-31  4368.455
# 2009-04-30 -1213.759
# 2009-05-31  -649.243
# 2009-06-30  2338.409

# %%
data_diff.columns
# Out:
# Index(['Value'], dtype='object')

# %%
# Check out what the differencing did to the time-series curve

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_diff)

# %%
dickey_fuller(data_diff)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                  -4.502056
# p-value                          0.000195
# Number of Lags Used             12.000000
# Number of Observations Used    141.000000
# Critical Value (1%)             -3.477601
# Critical Value (5%)             -2.882266
# Critical Value (10%)            -2.577822
# dtype: float64

# %% [markdown]
# After differentiating, the p-value shows that the results are statistically significant, and the test statistic (-4.5) is smaller than the critical value (-3.4), so we can reject the null hyothesis. There is no unit root, and the data is stationary so we can proceed with the forecast analyis.

# %%
plot_acf(data_diff)
plt.show()

# %% [markdown]
# After differentiating, the data also shows no significant outcorrelations outside the confidence interval.

# %% [markdown]
# ### 6. Forecasting with ARIMA

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(data_diff.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -4.502056
# p-value: 0.000195

# %% [markdown]
# p-value is below 0.05 so we can use the differenced series for ARIMA

# %% [markdown]
# #### 6.1 Define the Parameters

# %% [markdown]
# ARIMA parameters: d(number of times that differencing was done); p (parameter responsible for the autoregressive part, defines how many terms are taken into the regression to predict the next values); q (represents the moving average order, defines how many error terms will be considered).

# %% [markdown]
# It only took one differencing process to make the data stationary, so for ARIMA, the d parameter should be 1

# %%
# Plot partial autocorrelations to determine parameter p

plot_pacf(data_diff)
plt.figure(figsize=(15,15), dpi=300)
plt.show()

# %% [markdown]
# The partial autocorrelation shows only one highly positive bar, there don't seem to be many significant correlations, i would start with a low number (e.g, 2) for the p parameter.

# %%
#to determine parameter q, 
plot_acf(data_diff)
plt.show()

# %% [markdown]
# There are also no significant correlations, so i would start with a parameter q equal to 1

# %% [markdown]
# #### 6.2 Spliting the data

# %% [markdown]
# To split the data, which is monthly, i divided with training data up to mid-2017 and then a test set with data until the end of 2021. The goal has been to give some more time around 2020/2021 which are the covid years, and which would create some bias.

# %%
# Split the data

train = data_diff['Value'][:100]
test = data_diff['Value'][99:]

# %%
# Plot both sets in order to see the split

plt.figure(figsize=(15,5), dpi=100)
plt.plot(train)
plt.plot(test)

# %%
test.shape
# Out:
# (55,)

# %%
train.shape
# Out:
# (100,)

# %% [markdown]
# #### 6.3 Running and Fitting the Model

# %%
from statsmodels.tsa.arima.model import ARIMA # Import the model you need
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf

# %%
model = ARIMA(train, order=(2, 1, 2))  
fitted = model.fit()    
print(fitted.summary()) # Check model summary
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                  100
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1018.209
# Date:                Wed, 22 Mar 2023   AIC                           2046.418
# Time:                        16:34:05   BIC                           2059.393
# Sample:                    02-28-2009   HQIC                          2051.668
#                          - 05-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8267      0.120     -6.913      0.000      -1.061      -0.592
# ar.L2          0.1732      0.082      2.105      0.035       0.012       0.334
# ma.L1         -0.0017      2.756     -0.001      1.000      -5.403       5.400
# ma.L2         -0.9983      0.152     -6.551      0.000      -1.297      -0.700
# sigma2      4.778e+07    5.6e-08   8.53e+14      0.000    4.78e+07    4.78e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 4.95
# Prob(Q):                              0.79   Prob(JB):                         0.08
# Heteroskedasticity (H):               0.79   Skew:                            -0.34
# Prob(H) (two-sided):                  0.50   Kurtosis:                         3.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.28e+31. Standard errors may be unstable.

# %%
#Interating
model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit()    
print(fitted.summary()) # Check model summary
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                  100
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1018.951
# Date:                Wed, 22 Mar 2023   AIC                           2043.903
# Time:                        16:25:26   BIC                           2051.688
# Sample:                    02-28-2009   HQIC                          2047.053
#                          - 05-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1494      0.079      1.891      0.059      -0.005       0.304
# ma.L1         -1.0000      0.123     -8.124      0.000      -1.241      -0.759
# sigma2      4.908e+07   2.51e-09   1.96e+16      0.000    4.91e+07    4.91e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 3.43
# Prob(Q):                              0.86   Prob(JB):                         0.18
# Heteroskedasticity (H):               0.82   Skew:                            -0.22
# Prob(H) (two-sided):                  0.58   Kurtosis:                         3.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.52e+31. Standard errors may be unstable.

# %% [markdown]
# With 1,1,1 in the parameters the model works better, yet, the AIC indicates the model is not a good fit for the data

# %%
# Plotting Residual Errors  
myresiduals = pd.DataFrame(fitted.resid)  
fig, ax = plt.subplots(1,2)  
myresiduals.plot(title = "Residuals", ax = ax[0])  
myresiduals.plot(kind = 'kde', title = 'Density', ax = ax[1])  
plt.show()
